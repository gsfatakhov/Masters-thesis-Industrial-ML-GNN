# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
import time

# %% [markdown]
# ### Dataset:

# %%
try:
    from fddbenchmark import FDDDataset, FDDDataloader, FDDEvaluator
except:
    # !git clone https://github.com/airi-industrial-ai/fddbenchmark
    from fddbenchmark import FDDDataset, FDDDataloader, FDDEvaluator

# %%
tep_dataset = FDDDataset(name='reinartz_tep', splitting_type='supervised')
tep_dataset.df = (tep_dataset.df - tep_dataset.df.mean())/tep_dataset.df.std()
tep_dataset.df.head()
# Out:
# Reading data/reinartz_tep/dataset.csv: 100%|██████████| 5600000/5600000 [00:42<00:00, 133171.63it/s]
# Reading data/reinartz_tep/labels.csv: 100%|██████████| 5600000/5600000 [00:01<00:00, 3074981.19it/s]
# Reading data/reinartz_tep/train_mask.csv: 100%|██████████| 5600000/5600000 [00:01<00:00, 3047439.37it/s]
# Reading data/reinartz_tep/test_mask.csv: 100%|██████████| 5600000/5600000 [00:01<00:00, 3091692.67it/s]
#                     xmeas_1   xmeas_2   xmeas_3   xmeas_4   xmeas_5   xmeas_6  \
# run_id     sample
# 1334009671 1      -0.175458  0.097509 -0.092930  0.022772  0.079000  0.056226
#            2      -0.158513 -0.887449 -0.243139  0.211698 -0.352012 -0.553442
#            3      -0.166950  1.864230 -0.384321 -0.192391 -0.540460 -0.496256
#            4      -0.165755 -0.425304 -0.289450  0.085419  1.186139  0.114638
#            5      -0.179773  1.085111 -0.254781  0.393148 -0.116478 -0.816772
#
#                     xmeas_7   xmeas_8   xmeas_9  xmeas_10  ...     xmv_2  \
# run_id     sample                                          ...
# 1334009671 1       0.057243  0.078469 -0.042816 -0.081580  ... -0.101671
#            2      -0.006126 -0.248531 -0.358203 -0.098747  ... -0.037165
#            3       0.047474  0.041677  0.116272 -0.115753  ... -0.131093
#            4      -0.020781  0.570426  0.066785 -0.146494  ... -0.067351
#            5       0.051283 -0.513587 -0.061174 -0.184990  ... -0.059039
#
#                       xmv_3     xmv_4  xmv_5     xmv_6     xmv_7     xmv_8  \
# run_id     sample
# 1334009671 1      -0.237457 -0.139339    NaN -0.082903  0.236431  0.025629
#            2      -0.234886 -0.141768    NaN -0.105557  0.236835  0.066062
#            3      -0.232738 -0.140334    NaN -0.120353  0.108759 -0.071836
#            4      -0.231545 -0.160266    NaN -0.144987  0.036609 -0.135977
#            5      -0.230173 -0.122039    NaN -0.166149  0.122855  0.056399
#
#                    xmv_9    xmv_10    xmv_11
# run_id     sample
# 1334009671 1         NaN -0.149639 -1.448923
#            2         NaN -0.203725 -0.178945
#            3         NaN  0.048110  0.073242
#            4         NaN -0.178125  0.081174
#            5         NaN -0.243887  1.057207
#
# [5 rows x 52 columns]

# %%
tep_dataset.df['xmv_5'] = 1.0
tep_dataset.df['xmv_9'] = 1.0

# %% [markdown]
# ### Dataloader:

# %%
train_dl = FDDDataloader(
    dataframe=tep_dataset.df,
    mask=tep_dataset.train_mask,
    labels=tep_dataset.labels,
    window_size=100,
    step_size=1,
    minibatch_training=True,
    batch_size=512,
    shuffle=True
)

test_dl = FDDDataloader(
    dataframe=tep_dataset.df,
    mask=tep_dataset.test_mask,
    labels=tep_dataset.labels,
    window_size=100, 
    step_size=1, 
    minibatch_training=True,
    batch_size=512
)
# Out:
# Creating sequence of samples: 100%|██████████| 2240/2240 [01:37<00:00, 23.06it/s]
# Creating sequence of samples: 100%|██████████| 560/560 [00:23<00:00, 23.37it/s]

# %% [markdown]
# ### Model:

# %%
num_nodes = 52 # number of nodes
window_size = 100 # window size
ngnn = 4 # number of graph structure learning layers
gsllayer = 'relu' # type of graph structure learning layer ('relu', 'directed', 'unidirected', 'undirected')
nhidden = 256 # feature size in GCN layers
alpha = 0.1 # hyperparameter for weights of edges
k = None # max number of edges for each node
out_channels = 29 # number of process states

# %%
from models import *

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = GNNTEP(num_nodes, window_size, ngnn, gsllayer, nhidden,
               alpha, k, out_channels, device)

# %% [markdown]
# ### Training:

# %%
model.to(device)
optimizer = Adam(model.parameters(), lr=0.001)
n_epochs = 50

# %%
# %%time
for e in range(n_epochs):
    model.train()
    av_loss = []
    for train_ts, train_index, train_label in train_dl:
        m = torch.FloatTensor(train_ts)
        v_train_ts = torch.transpose(m, 1, 2)
        train_label = torch.LongTensor(train_label.values).to(device)
        weight = torch.ones(29) * 0.5
        weight[1:] /= 20
        logits = model(v_train_ts)
        loss = F.cross_entropy(logits, train_label, weight=weight.to(device))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        av_loss.append(loss.item())
    print(f'Epoch: {e+1:2d}/{n_epochs}, average CE loss: {sum(av_loss)/len(av_loss):.4f}')
    
    preds = []
    test_labels = []
    model.eval()
    for test_ts, test_index, test_label in test_dl:
        m = torch.FloatTensor(test_ts)
        v_test_ts = torch.transpose(m, 1, 2)
        with torch.no_grad():
            logits = model(v_test_ts)
        pred = logits.argmax(axis=1).cpu().numpy()
        preds.append(pd.Series(pred, index=test_index))
        test_labels.append(test_label)
    pred = pd.concat(preds)
    test_label = pd.concat(test_labels)
    
    evaluator = FDDEvaluator(
    splitting_type=tep_dataset.splitting_type, 
    step_size=test_dl.step_size
    )
    evaluator.print_metrics(test_label, pred)
    
    torch.save(model, 'directed_epoch_'+str(e+1)+'.pth')
# Out:
# Epoch:  1/50, average CE loss: 0.1539
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9950/0.0000
#     Fault 02: 0.9906/0.0000
#     Fault 03: 0.9331/0.0003
#     Fault 04: 0.9986/0.0000
#     Fault 05: 0.9784/0.0000
#     Fault 06: 0.9982/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9794/0.0000
#     Fault 09: 0.3144/0.0004
#     Fault 10: 0.9704/0.0000
#     Fault 11: 0.9886/0.0000
#     Fault 12: 0.9818/0.0000
#     Fault 13: 0.9581/0.0000
#     Fault 14: 0.9964/0.0000
#     Fault 15: 0.0092/0.0000
#     Fault 16: 0.4962/0.0006
#     Fault 17: 0.9757/0.0000
#     Fault 18: 0.9584/0.0000
#     Fault 19: 0.9884/0.0000
#     Fault 20: 0.9701/0.0000
#     Fault 21: 0.0000/0.0000
#     Fault 22: 0.7031/0.0000
#     Fault 23: 0.0000/0.0000
#     Fault 24: 0.9902/0.0000
#     Fault 25: 0.9883/0.0000
#     Fault 26: 0.9796/0.0000
#     Fault 27: 0.9894/0.0000
#     Fault 28: 0.9550/0.0000
# Detection TPR: 0.8508
# Detection FPR: 0.0013
# Average Detection Delay (ADD): 55.85
# Total Correct Diagnosis Rate (Total CDR): 0.9691
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.6754
# Normalized Mutual Information (NMI): 0.8904
# Unsupervised Clustering Accuracy (ACC): 0.8703
# Epoch:  2/50, average CE loss: 0.1012
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9960/0.0000
#     Fault 02: 0.9918/0.0000
#     Fault 03: 0.9489/0.0003
#     Fault 04: 0.9986/0.0000
#     Fault 05: 0.9888/0.0000
#     Fault 06: 0.9993/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9778/0.0000
#     Fault 09: 0.3664/0.0002
#     Fault 10: 0.9729/0.0000
#     Fault 11: 0.9896/0.0000
#     Fault 12: 0.9848/0.0000
#     Fault 13: 0.9719/0.0000
#     Fault 14: 0.9959/0.0000
#     Fault 15: 0.0312/0.0001
#     Fault 16: 0.5804/0.0009
#     Fault 17: 0.9757/0.0000
#     Fault 18: 0.9610/0.0000
#     Fault 19: 0.9906/0.0000
#     Fault 20: 0.9705/0.0000
#     Fault 21: 0.0000/0.0000
#     Fault 22: 0.7384/0.0000
#     Fault 23: 0.8241/0.0010
#     Fault 24: 0.9906/0.0000
#     Fault 25: 0.9892/0.0000
#     Fault 26: 0.9819/0.0000
#     Fault 27: 0.9929/0.0000
#     Fault 28: 0.9596/0.0000
# Detection TPR: 0.8887
# Detection FPR: 0.0025
# Average Detection Delay (ADD): 43.32
# Total Correct Diagnosis Rate (Total CDR): 0.9712
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.7444
# Normalized Mutual Information (NMI): 0.9077
# Unsupervised Clustering Accuracy (ACC): 0.8985
# Epoch:  3/50, average CE loss: 0.0851
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9959/0.0000
#     Fault 02: 0.9924/0.0000
#     Fault 03: 0.9474/0.0003
#     Fault 04: 0.9985/0.0000
#     Fault 05: 0.9878/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9807/0.0000
#     Fault 09: 0.3800/0.0002
#     Fault 10: 0.9741/0.0000
#     Fault 11: 0.9912/0.0000
#     Fault 12: 0.9848/0.0000
#     Fault 13: 0.9722/0.0000
#     Fault 14: 0.9957/0.0000
#     Fault 15: 0.0409/0.0000
#     Fault 16: 0.6224/0.0008
#     Fault 17: 0.9760/0.0000
#     Fault 18: 0.9633/0.0000
#     Fault 19: 0.9923/0.0000
#     Fault 20: 0.9704/0.0000
#     Fault 21: 0.0000/0.0000
#     Fault 22: 0.7538/0.0000
#     Fault 23: 0.8435/0.0002
#     Fault 24: 0.9908/0.0000
#     Fault 25: 0.9891/0.0000
#     Fault 26: 0.9816/0.0000
#     Fault 27: 0.9924/0.0000
#     Fault 28: 0.9560/0.0000
# Detection TPR: 0.8925
# Detection FPR: 0.0014
# Average Detection Delay (ADD): 43.14
# Total Correct Diagnosis Rate (Total CDR): 0.9713
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.7529
# Normalized Mutual Information (NMI): 0.9112
# Unsupervised Clustering Accuracy (ACC): 0.9015
# Epoch:  4/50, average CE loss: 0.0781
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9955/0.0000
#     Fault 02: 0.9929/0.0000
#     Fault 03: 0.9556/0.0003
#     Fault 04: 0.9985/0.0000
#     Fault 05: 0.9895/0.0000
#     Fault 06: 0.9993/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9782/0.0000
#     Fault 09: 0.4821/0.0002
#     Fault 10: 0.9751/0.0000
#     Fault 11: 0.9918/0.0000
#     Fault 12: 0.9855/0.0000
#     Fault 13: 0.9729/0.0000
#     Fault 14: 0.9955/0.0000
#     Fault 15: 0.1017/0.0002
#     Fault 16: 0.6914/0.0009
#     Fault 17: 0.9762/0.0000
#     Fault 18: 0.9637/0.0000
#     Fault 19: 0.9926/0.0000
#     Fault 20: 0.9709/0.0000
#     Fault 21: 0.0000/0.0000
#     Fault 22: 0.6783/0.0000
#     Fault 23: 0.9060/0.0004
#     Fault 24: 0.9910/0.0000
#     Fault 25: 0.9886/0.0000
#     Fault 26: 0.9819/0.0000
#     Fault 27: 0.9924/0.0000
#     Fault 28: 0.9589/0.0000
# Detection TPR: 0.9006
# Detection FPR: 0.0020
# Average Detection Delay (ADD): 38.88
# Total Correct Diagnosis Rate (Total CDR): 0.9717
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.7687
# Normalized Mutual Information (NMI): 0.9151
# Unsupervised Clustering Accuracy (ACC): 0.9075
# Epoch:  5/50, average CE loss: 0.0735
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9965/0.0000
#     Fault 02: 0.9930/0.0000
#     Fault 03: 0.9633/0.0003
#     Fault 04: 0.9986/0.0000
#     Fault 05: 0.9898/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9808/0.0000
#     Fault 09: 0.5201/0.0002
#     Fault 10: 0.9754/0.0000
#     Fault 11: 0.9922/0.0000
#     Fault 12: 0.9859/0.0000
#     Fault 13: 0.9718/0.0000
#     Fault 14: 0.9957/0.0000
#     Fault 15: 0.1552/0.0005
#     Fault 16: 0.7568/0.0009
#     Fault 17: 0.9767/0.0000
#     Fault 18: 0.9641/0.0000
#     Fault 19: 0.9928/0.0000
#     Fault 20: 0.9711/0.0000
#     Fault 21: 0.0000/0.0000
#     Fault 22: 0.6572/0.0000
#     Fault 23: 0.9373/0.0008
#     Fault 24: 0.9911/0.0000
#     Fault 25: 0.9890/0.0000
#     Fault 26: 0.9824/0.0000
#     Fault 27: 0.9912/0.0000
#     Fault 28: 0.9631/0.0000
# Detection TPR: 0.9070
# Detection FPR: 0.0027
# Average Detection Delay (ADD): 37.18
# Total Correct Diagnosis Rate (Total CDR): 0.9721
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.7812
# Normalized Mutual Information (NMI): 0.9185
# Unsupervised Clustering Accuracy (ACC): 0.9121
# Epoch:  6/50, average CE loss: 0.0695
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9966/0.0000
#     Fault 02: 0.9931/0.0000
#     Fault 03: 0.9686/0.0002
#     Fault 04: 0.9986/0.0000
#     Fault 05: 0.9900/0.0000
#     Fault 06: 0.9993/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9817/0.0000
#     Fault 09: 0.5260/0.0002
#     Fault 10: 0.9752/0.0000
#     Fault 11: 0.9908/0.0000
#     Fault 12: 0.9865/0.0000
#     Fault 13: 0.9734/0.0000
#     Fault 14: 0.9962/0.0000
#     Fault 15: 0.2916/0.0024
#     Fault 16: 0.8406/0.0017
#     Fault 17: 0.9775/0.0000
#     Fault 18: 0.9641/0.0000
#     Fault 19: 0.9929/0.0000
#     Fault 20: 0.9712/0.0000
#     Fault 21: 0.0000/0.0000
#     Fault 22: 0.6597/0.0000
#     Fault 23: 0.9429/0.0005
#     Fault 24: 0.9910/0.0000
#     Fault 25: 0.9891/0.0000
#     Fault 26: 0.9826/0.0000
#     Fault 27: 0.9924/0.0000
#     Fault 28: 0.9640/0.0000
# Detection TPR: 0.9164
# Detection FPR: 0.0051
# Average Detection Delay (ADD): 33.21
# Total Correct Diagnosis Rate (Total CDR): 0.9718
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.7982
# Normalized Mutual Information (NMI): 0.9216
# Unsupervised Clustering Accuracy (ACC): 0.9180
# Epoch:  7/50, average CE loss: 0.0660
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9966/0.0000
#     Fault 02: 0.9933/0.0000
#     Fault 03: 0.9770/0.0001
#     Fault 04: 0.9983/0.0000
#     Fault 05: 0.9896/0.0000
#     Fault 06: 0.9993/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9827/0.0000
#     Fault 09: 0.5669/0.0001
#     Fault 10: 0.9760/0.0000
#     Fault 11: 0.9934/0.0000
#     Fault 12: 0.9869/0.0000
#     Fault 13: 0.9720/0.0000
#     Fault 14: 0.9965/0.0000
#     Fault 15: 0.2223/0.0010
#     Fault 16: 0.8205/0.0006
#     Fault 17: 0.9788/0.0000
#     Fault 18: 0.9641/0.0000
#     Fault 19: 0.9930/0.0000
#     Fault 20: 0.9709/0.0000
#     Fault 21: 0.0000/0.0000
#     Fault 22: 0.6658/0.0000
#     Fault 23: 0.9337/0.0004
#     Fault 24: 0.9908/0.0000
#     Fault 25: 0.9898/0.0000
#     Fault 26: 0.9822/0.0000
#     Fault 27: 0.9875/0.0000
#     Fault 28: 0.9570/0.0000
# Detection TPR: 0.9146
# Detection FPR: 0.0022
# Average Detection Delay (ADD): 33.77
# Total Correct Diagnosis Rate (Total CDR): 0.9716
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.7973
# Normalized Mutual Information (NMI): 0.9233
# Unsupervised Clustering Accuracy (ACC): 0.9174
# Epoch:  8/50, average CE loss: 0.0630
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9964/0.0000
#     Fault 02: 0.9935/0.0000
#     Fault 03: 0.9826/0.0000
#     Fault 04: 0.9982/0.0000
#     Fault 05: 0.9920/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9820/0.0000
#     Fault 09: 0.6239/0.0001
#     Fault 10: 0.9758/0.0000
#     Fault 11: 0.9919/0.0000
#     Fault 12: 0.9865/0.0000
#     Fault 13: 0.9732/0.0000
#     Fault 14: 0.9974/0.0000
#     Fault 15: 0.3352/0.0033
#     Fault 16: 0.8495/0.0008
#     Fault 17: 0.9790/0.0000
#     Fault 18: 0.9641/0.0000
#     Fault 19: 0.9929/0.0000
#     Fault 20: 0.9711/0.0000
#     Fault 21: 0.0000/0.0000
#     Fault 22: 0.6351/0.0000
#     Fault 23: 0.9043/0.0000
#     Fault 24: 0.9910/0.0000
#     Fault 25: 0.9896/0.0000
#     Fault 26: 0.9830/0.0000
#     Fault 27: 0.9823/0.0000
#     Fault 28: 0.9612/0.0000
# Detection TPR: 0.9201
# Detection FPR: 0.0043
# Average Detection Delay (ADD): 37.72
# Total Correct Diagnosis Rate (Total CDR): 0.9715
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8063
# Normalized Mutual Information (NMI): 0.9244
# Unsupervised Clustering Accuracy (ACC): 0.9207
# Epoch:  9/50, average CE loss: 0.0606
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9962/0.0000
#     Fault 02: 0.9939/0.0000
#     Fault 03: 0.9820/0.0000
#     Fault 04: 0.9982/0.0000
#     Fault 05: 0.9879/0.0000
#     Fault 06: 0.9993/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9818/0.0000
#     Fault 09: 0.6069/0.0000
#     Fault 10: 0.9762/0.0000
#     Fault 11: 0.9918/0.0000
#     Fault 12: 0.9865/0.0000
#     Fault 13: 0.9735/0.0000
#     Fault 14: 0.9960/0.0000
#     Fault 15: 0.2706/0.0018
#     Fault 16: 0.8702/0.0008
#     Fault 17: 0.9789/0.0000
#     Fault 18: 0.9637/0.0000
#     Fault 19: 0.9930/0.0000
#     Fault 20: 0.9711/0.0000
#     Fault 21: 0.0000/0.0000
#     Fault 22: 0.6455/0.0000
#     Fault 23: 0.9475/0.0003
#     Fault 24: 0.9908/0.0000
#     Fault 25: 0.9898/0.0000
#     Fault 26: 0.9831/0.0000
#     Fault 27: 0.9923/0.0000
#     Fault 28: 0.9622/0.0000
# Detection TPR: 0.9200
# Detection FPR: 0.0029
# Average Detection Delay (ADD): 36.50
# Total Correct Diagnosis Rate (Total CDR): 0.9715
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8081
# Normalized Mutual Information (NMI): 0.9267
# Unsupervised Clustering Accuracy (ACC): 0.9210
# Epoch: 10/50, average CE loss: 0.0584
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9957/0.0000
#     Fault 02: 0.9942/0.0000
#     Fault 03: 0.9835/0.0000
#     Fault 04: 0.9985/0.0000
#     Fault 05: 0.9870/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9817/0.0000
#     Fault 09: 0.6696/0.0000
#     Fault 10: 0.9749/0.0000
#     Fault 11: 0.9918/0.0000
#     Fault 12: 0.9869/0.0000
#     Fault 13: 0.9744/0.0000
#     Fault 14: 0.9965/0.0000
#     Fault 15: 0.2770/0.0019
#     Fault 16: 0.8844/0.0008
#     Fault 17: 0.9794/0.0000
#     Fault 18: 0.9641/0.0000
#     Fault 19: 0.9930/0.0000
#     Fault 20: 0.9709/0.0000
#     Fault 21: 0.0000/0.0000
#     Fault 22: 0.5855/0.0000
#     Fault 23: 0.9494/0.0011
#     Fault 24: 0.9910/0.0000
#     Fault 25: 0.9897/0.0000
#     Fault 26: 0.9819/0.0000
#     Fault 27: 0.9900/0.0000
#     Fault 28: 0.9550/0.0000
# Detection TPR: 0.9208
# Detection FPR: 0.0039
# Average Detection Delay (ADD): 32.72
# Total Correct Diagnosis Rate (Total CDR): 0.9713
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8089
# Normalized Mutual Information (NMI): 0.9261
# Unsupervised Clustering Accuracy (ACC): 0.9212
# Epoch: 11/50, average CE loss: 0.0565
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9955/0.0000
#     Fault 02: 0.9946/0.0000
#     Fault 03: 0.9836/0.0000
#     Fault 04: 0.9985/0.0000
#     Fault 05: 0.9874/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9816/0.0000
#     Fault 09: 0.6012/0.0000
#     Fault 10: 0.9752/0.0000
#     Fault 11: 0.9917/0.0000
#     Fault 12: 0.9856/0.0000
#     Fault 13: 0.9740/0.0000
#     Fault 14: 0.9961/0.0000
#     Fault 15: 0.2585/0.0017
#     Fault 16: 0.8860/0.0006
#     Fault 17: 0.9793/0.0000
#     Fault 18: 0.9642/0.0000
#     Fault 19: 0.9930/0.0000
#     Fault 20: 0.9708/0.0000
#     Fault 21: 0.0000/0.0000
#     Fault 22: 0.6499/0.0000
#     Fault 23: 0.9533/0.0006
#     Fault 24: 0.9910/0.0000
#     Fault 25: 0.9893/0.0000
#     Fault 26: 0.9821/0.0000
#     Fault 27: 0.9912/0.0000
#     Fault 28: 0.9608/0.0000
# Detection TPR: 0.9205
# Detection FPR: 0.0031
# Average Detection Delay (ADD): 36.26
# Total Correct Diagnosis Rate (Total CDR): 0.9712
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8092
# Normalized Mutual Information (NMI): 0.9271
# Unsupervised Clustering Accuracy (ACC): 0.9211
# Epoch: 12/50, average CE loss: 0.0547
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9961/0.0000
#     Fault 02: 0.9948/0.0000
#     Fault 03: 0.9832/0.0000
#     Fault 04: 0.9984/0.0000
#     Fault 05: 0.9883/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9765/0.0000
#     Fault 09: 0.5797/0.0000
#     Fault 10: 0.9747/0.0000
#     Fault 11: 0.9927/0.0000
#     Fault 12: 0.9855/0.0000
#     Fault 13: 0.9735/0.0000
#     Fault 14: 0.9957/0.0000
#     Fault 15: 0.2848/0.0020
#     Fault 16: 0.8890/0.0005
#     Fault 17: 0.9791/0.0000
#     Fault 18: 0.9639/0.0000
#     Fault 19: 0.9926/0.0000
#     Fault 20: 0.9706/0.0000
#     Fault 21: 0.0000/0.0000
#     Fault 22: 0.6641/0.0000
#     Fault 23: 0.9565/0.0009
#     Fault 24: 0.9910/0.0000
#     Fault 25: 0.9898/0.0000
#     Fault 26: 0.9820/0.0000
#     Fault 27: 0.9885/0.0000
#     Fault 28: 0.9609/0.0000
# Detection TPR: 0.9217
# Detection FPR: 0.0035
# Average Detection Delay (ADD): 33.35
# Total Correct Diagnosis Rate (Total CDR): 0.9706
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8111
# Normalized Mutual Information (NMI): 0.9265
# Unsupervised Clustering Accuracy (ACC): 0.9214
# Epoch: 13/50, average CE loss: 0.0532
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9959/0.0000
#     Fault 02: 0.9947/0.0000
#     Fault 03: 0.9833/0.0000
#     Fault 04: 0.9986/0.0000
#     Fault 05: 0.9861/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9813/0.0000
#     Fault 09: 0.5567/0.0000
#     Fault 10: 0.9761/0.0000
#     Fault 11: 0.9906/0.0000
#     Fault 12: 0.9858/0.0000
#     Fault 13: 0.9738/0.0000
#     Fault 14: 0.9961/0.0000
#     Fault 15: 0.3017/0.0025
#     Fault 16: 0.8825/0.0003
#     Fault 17: 0.9789/0.0000
#     Fault 18: 0.9642/0.0000
#     Fault 19: 0.9927/0.0000
#     Fault 20: 0.9709/0.0000
#     Fault 21: 0.0000/0.0000
#     Fault 22: 0.6859/0.0000
#     Fault 23: 0.9612/0.0011
#     Fault 24: 0.9910/0.0000
#     Fault 25: 0.9891/0.0000
#     Fault 26: 0.9806/0.0000
#     Fault 27: 0.9916/0.0000
#     Fault 28: 0.9646/0.0000
# Detection TPR: 0.9226
# Detection FPR: 0.0040
# Average Detection Delay (ADD): 39.99
# Total Correct Diagnosis Rate (Total CDR): 0.9705
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8127
# Normalized Mutual Information (NMI): 0.9274
# Unsupervised Clustering Accuracy (ACC): 0.9219
# Epoch: 14/50, average CE loss: 0.0517
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9943/0.0000
#     Fault 02: 0.9943/0.0000
#     Fault 03: 0.9835/0.0000
#     Fault 04: 0.9984/0.0000
#     Fault 05: 0.9894/0.0000
#     Fault 06: 0.9990/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9821/0.0000
#     Fault 09: 0.5931/0.0000
#     Fault 10: 0.9756/0.0000
#     Fault 11: 0.9910/0.0000
#     Fault 12: 0.9855/0.0000
#     Fault 13: 0.9736/0.0000
#     Fault 14: 0.9972/0.0000
#     Fault 15: 0.3621/0.0043
#     Fault 16: 0.9159/0.0011
#     Fault 17: 0.9791/0.0000
#     Fault 18: 0.9639/0.0000
#     Fault 19: 0.9929/0.0000
#     Fault 20: 0.9709/0.0000
#     Fault 21: 0.0000/0.0000
#     Fault 22: 0.6490/0.0000
#     Fault 23: 0.9583/0.0007
#     Fault 24: 0.9910/0.0000
#     Fault 25: 0.9891/0.0000
#     Fault 26: 0.9814/0.0000
#     Fault 27: 0.9846/0.0000
#     Fault 28: 0.9647/0.0001
# Detection TPR: 0.9263
# Detection FPR: 0.0062
# Average Detection Delay (ADD): 35.65
# Total Correct Diagnosis Rate (Total CDR): 0.9701
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8182
# Normalized Mutual Information (NMI): 0.9274
# Unsupervised Clustering Accuracy (ACC): 0.9236
# Epoch: 15/50, average CE loss: 0.0503
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9949/0.0000
#     Fault 02: 0.9945/0.0000
#     Fault 03: 0.9822/0.0000
#     Fault 04: 0.9986/0.0000
#     Fault 05: 0.9872/0.0000
#     Fault 06: 0.9991/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9809/0.0000
#     Fault 09: 0.5779/0.0000
#     Fault 10: 0.9751/0.0000
#     Fault 11: 0.9916/0.0000
#     Fault 12: 0.9854/0.0000
#     Fault 13: 0.9737/0.0000
#     Fault 14: 0.9961/0.0000
#     Fault 15: 0.3594/0.0050
#     Fault 16: 0.8854/0.0003
#     Fault 17: 0.9795/0.0000
#     Fault 18: 0.9637/0.0000
#     Fault 19: 0.9925/0.0000
#     Fault 20: 0.9710/0.0000
#     Fault 21: 0.0000/0.0000
#     Fault 22: 0.6759/0.0000
#     Fault 23: 0.9602/0.0008
#     Fault 24: 0.9910/0.0000
#     Fault 25: 0.9884/0.0000
#     Fault 26: 0.9812/0.0000
#     Fault 27: 0.9893/0.0000
#     Fault 28: 0.9649/0.0001
# Detection TPR: 0.9252
# Detection FPR: 0.0062
# Average Detection Delay (ADD): 35.92
# Total Correct Diagnosis Rate (Total CDR): 0.9703
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8160
# Normalized Mutual Information (NMI): 0.9272
# Unsupervised Clustering Accuracy (ACC): 0.9230
# Epoch: 16/50, average CE loss: 0.0490
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9943/0.0000
#     Fault 02: 0.9932/0.0000
#     Fault 03: 0.9815/0.0000
#     Fault 04: 0.9985/0.0000
#     Fault 05: 0.9886/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9824/0.0000
#     Fault 09: 0.5901/0.0000
#     Fault 10: 0.9755/0.0000
#     Fault 11: 0.9903/0.0000
#     Fault 12: 0.9849/0.0000
#     Fault 13: 0.9740/0.0000
#     Fault 14: 0.9962/0.0000
#     Fault 15: 0.4300/0.0079
#     Fault 16: 0.9067/0.0008
#     Fault 17: 0.9791/0.0000
#     Fault 18: 0.9639/0.0000
#     Fault 19: 0.9928/0.0000
#     Fault 20: 0.9708/0.0000
#     Fault 21: 0.0000/0.0000
#     Fault 22: 0.6601/0.0000
#     Fault 23: 0.9611/0.0010
#     Fault 24: 0.9908/0.0000
#     Fault 25: 0.9889/0.0000
#     Fault 26: 0.9802/0.0000
#     Fault 27: 0.9896/0.0000
#     Fault 28: 0.9674/0.0002
# Detection TPR: 0.9291
# Detection FPR: 0.0101
# Average Detection Delay (ADD): 30.74
# Total Correct Diagnosis Rate (Total CDR): 0.9698
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8209
# Normalized Mutual Information (NMI): 0.9271
# Unsupervised Clustering Accuracy (ACC): 0.9244
# Epoch: 17/50, average CE loss: 0.0479
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9942/0.0000
#     Fault 02: 0.9941/0.0001
#     Fault 03: 0.9791/0.0000
#     Fault 04: 0.9985/0.0000
#     Fault 05: 0.9876/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9805/0.0000
#     Fault 09: 0.5706/0.0000
#     Fault 10: 0.9754/0.0000
#     Fault 11: 0.9902/0.0000
#     Fault 12: 0.9858/0.0000
#     Fault 13: 0.9741/0.0001
#     Fault 14: 0.9959/0.0000
#     Fault 15: 0.3781/0.0051
#     Fault 16: 0.9165/0.0009
#     Fault 17: 0.9790/0.0000
#     Fault 18: 0.9640/0.0000
#     Fault 19: 0.9926/0.0000
#     Fault 20: 0.9708/0.0000
#     Fault 21: 0.0000/0.0000
#     Fault 22: 0.6784/0.0000
#     Fault 23: 0.9647/0.0014
#     Fault 24: 0.9904/0.0000
#     Fault 25: 0.9896/0.0000
#     Fault 26: 0.9808/0.0000
#     Fault 27: 0.9919/0.0000
#     Fault 28: 0.9656/0.0001
# Detection TPR: 0.9275
# Detection FPR: 0.0077
# Average Detection Delay (ADD): 32.75
# Total Correct Diagnosis Rate (Total CDR): 0.9699
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8196
# Normalized Mutual Information (NMI): 0.9274
# Unsupervised Clustering Accuracy (ACC): 0.9239
# Epoch: 18/50, average CE loss: 0.0469
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9943/0.0000
#     Fault 02: 0.9939/0.0000
#     Fault 03: 0.9829/0.0000
#     Fault 04: 0.9984/0.0000
#     Fault 05: 0.9870/0.0000
#     Fault 06: 0.9991/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9791/0.0000
#     Fault 09: 0.6508/0.0000
#     Fault 10: 0.9739/0.0000
#     Fault 11: 0.9911/0.0000
#     Fault 12: 0.9854/0.0000
#     Fault 13: 0.9742/0.0000
#     Fault 14: 0.9956/0.0000
#     Fault 15: 0.4789/0.0120
#     Fault 16: 0.8890/0.0003
#     Fault 17: 0.9785/0.0000
#     Fault 18: 0.9638/0.0000
#     Fault 19: 0.9925/0.0000
#     Fault 20: 0.9712/0.0000
#     Fault 21: 0.0000/0.0000
#     Fault 22: 0.5893/0.0000
#     Fault 23: 0.9546/0.0005
#     Fault 24: 0.9908/0.0000
#     Fault 25: 0.9886/0.0000
#     Fault 26: 0.9809/0.0000
#     Fault 27: 0.9906/0.0000
#     Fault 28: 0.9669/0.0002
# Detection TPR: 0.9299
# Detection FPR: 0.0132
# Average Detection Delay (ADD): 29.36
# Total Correct Diagnosis Rate (Total CDR): 0.9694
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8197
# Normalized Mutual Information (NMI): 0.9256
# Unsupervised Clustering Accuracy (ACC): 0.9239
# Epoch: 19/50, average CE loss: 0.0458
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9945/0.0000
#     Fault 02: 0.9942/0.0001
#     Fault 03: 0.9812/0.0000
#     Fault 04: 0.9984/0.0000
#     Fault 05: 0.9880/0.0000
#     Fault 06: 0.9989/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9828/0.0000
#     Fault 09: 0.5819/0.0000
#     Fault 10: 0.9745/0.0000
#     Fault 11: 0.9905/0.0000
#     Fault 12: 0.9856/0.0000
#     Fault 13: 0.9734/0.0001
#     Fault 14: 0.9962/0.0000
#     Fault 15: 0.3955/0.0064
#     Fault 16: 0.8929/0.0004
#     Fault 17: 0.9786/0.0001
#     Fault 18: 0.9636/0.0000
#     Fault 19: 0.9924/0.0000
#     Fault 20: 0.9706/0.0000
#     Fault 21: 0.0001/0.0001
#     Fault 22: 0.6667/0.0000
#     Fault 23: 0.9663/0.0033
#     Fault 24: 0.9908/0.0000
#     Fault 25: 0.9885/0.0000
#     Fault 26: 0.9796/0.0000
#     Fault 27: 0.9910/0.0000
#     Fault 28: 0.9633/0.0001
# Detection TPR: 0.9275
# Detection FPR: 0.0105
# Average Detection Delay (ADD): 30.11
# Total Correct Diagnosis Rate (Total CDR): 0.9695
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8172
# Normalized Mutual Information (NMI): 0.9256
# Unsupervised Clustering Accuracy (ACC): 0.9230
# Epoch: 20/50, average CE loss: 0.0447
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9946/0.0000
#     Fault 02: 0.9940/0.0000
#     Fault 03: 0.9799/0.0000
#     Fault 04: 0.9985/0.0000
#     Fault 05: 0.9887/0.0000
#     Fault 06: 0.9990/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9810/0.0000
#     Fault 09: 0.6215/0.0000
#     Fault 10: 0.9746/0.0000
#     Fault 11: 0.9878/0.0000
#     Fault 12: 0.9859/0.0000
#     Fault 13: 0.9716/0.0001
#     Fault 14: 0.9966/0.0000
#     Fault 15: 0.4196/0.0085
#     Fault 16: 0.9111/0.0007
#     Fault 17: 0.9790/0.0001
#     Fault 18: 0.9638/0.0000
#     Fault 19: 0.9923/0.0000
#     Fault 20: 0.9707/0.0000
#     Fault 21: 0.0003/0.0002
#     Fault 22: 0.6211/0.0000
#     Fault 23: 0.9477/0.0002
#     Fault 24: 0.9907/0.0000
#     Fault 25: 0.9887/0.0000
#     Fault 26: 0.9801/0.0000
#     Fault 27: 0.9916/0.0000
#     Fault 28: 0.9646/0.0001
# Detection TPR: 0.9284
# Detection FPR: 0.0100
# Average Detection Delay (ADD): 30.75
# Total Correct Diagnosis Rate (Total CDR): 0.9692
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8193
# Normalized Mutual Information (NMI): 0.9261
# Unsupervised Clustering Accuracy (ACC): 0.9235
# Epoch: 21/50, average CE loss: 0.0439
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9937/0.0000
#     Fault 02: 0.9939/0.0001
#     Fault 03: 0.9751/0.0000
#     Fault 04: 0.9985/0.0000
#     Fault 05: 0.9866/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9820/0.0000
#     Fault 09: 0.5519/0.0000
#     Fault 10: 0.9752/0.0000
#     Fault 11: 0.9907/0.0000
#     Fault 12: 0.9855/0.0000
#     Fault 13: 0.9726/0.0001
#     Fault 14: 0.9960/0.0000
#     Fault 15: 0.3539/0.0047
#     Fault 16: 0.8937/0.0003
#     Fault 17: 0.9785/0.0001
#     Fault 18: 0.9631/0.0000
#     Fault 19: 0.9922/0.0000
#     Fault 20: 0.9713/0.0000
#     Fault 21: 0.0002/0.0002
#     Fault 22: 0.6827/0.0000
#     Fault 23: 0.9465/0.0001
#     Fault 24: 0.9909/0.0000
#     Fault 25: 0.9871/0.0000
#     Fault 26: 0.9799/0.0000
#     Fault 27: 0.9880/0.0000
#     Fault 28: 0.9630/0.0001
# Detection TPR: 0.9248
# Detection FPR: 0.0058
# Average Detection Delay (ADD): 32.21
# Total Correct Diagnosis Rate (Total CDR): 0.9690
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8152
# Normalized Mutual Information (NMI): 0.9261
# Unsupervised Clustering Accuracy (ACC): 0.9219
# Epoch: 22/50, average CE loss: 0.0430
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9946/0.0000
#     Fault 02: 0.9937/0.0001
#     Fault 03: 0.9794/0.0000
#     Fault 04: 0.9984/0.0000
#     Fault 05: 0.9865/0.0000
#     Fault 06: 0.9991/0.0000
#     Fault 07: 0.9985/0.0000
#     Fault 08: 0.9820/0.0000
#     Fault 09: 0.5536/0.0000
#     Fault 10: 0.9735/0.0000
#     Fault 11: 0.9895/0.0000
#     Fault 12: 0.9854/0.0000
#     Fault 13: 0.9731/0.0000
#     Fault 14: 0.9958/0.0000
#     Fault 15: 0.4044/0.0073
#     Fault 16: 0.9048/0.0007
#     Fault 17: 0.9785/0.0001
#     Fault 18: 0.9637/0.0000
#     Fault 19: 0.9920/0.0000
#     Fault 20: 0.9709/0.0000
#     Fault 21: 0.0003/0.0004
#     Fault 22: 0.6806/0.0000
#     Fault 23: 0.9626/0.0010
#     Fault 24: 0.9904/0.0000
#     Fault 25: 0.9891/0.0000
#     Fault 26: 0.9807/0.0000
#     Fault 27: 0.9891/0.0000
#     Fault 28: 0.9657/0.0001
# Detection TPR: 0.9280
# Detection FPR: 0.0098
# Average Detection Delay (ADD): 30.58
# Total Correct Diagnosis Rate (Total CDR): 0.9689
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8189
# Normalized Mutual Information (NMI): 0.9260
# Unsupervised Clustering Accuracy (ACC): 0.9231
# Epoch: 23/50, average CE loss: 0.0421
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9950/0.0000
#     Fault 02: 0.9939/0.0001
#     Fault 03: 0.9769/0.0000
#     Fault 04: 0.9982/0.0000
#     Fault 05: 0.9870/0.0000
#     Fault 06: 0.9991/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9810/0.0000
#     Fault 09: 0.5212/0.0000
#     Fault 10: 0.9741/0.0000
#     Fault 11: 0.9906/0.0000
#     Fault 12: 0.9852/0.0001
#     Fault 13: 0.9712/0.0001
#     Fault 14: 0.9962/0.0000
#     Fault 15: 0.3955/0.0071
#     Fault 16: 0.9270/0.0018
#     Fault 17: 0.9784/0.0001
#     Fault 18: 0.9634/0.0000
#     Fault 19: 0.9924/0.0000
#     Fault 20: 0.9711/0.0000
#     Fault 21: 0.0006/0.0005
#     Fault 22: 0.7058/0.0000
#     Fault 23: 0.9495/0.0001
#     Fault 24: 0.9908/0.0000
#     Fault 25: 0.9889/0.0000
#     Fault 26: 0.9810/0.0000
#     Fault 27: 0.9912/0.0000
#     Fault 28: 0.9657/0.0002
# Detection TPR: 0.9283
# Detection FPR: 0.0103
# Average Detection Delay (ADD): 30.83
# Total Correct Diagnosis Rate (Total CDR): 0.9683
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8192
# Normalized Mutual Information (NMI): 0.9260
# Unsupervised Clustering Accuracy (ACC): 0.9228
# Epoch: 24/50, average CE loss: 0.0414
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9947/0.0000
#     Fault 02: 0.9940/0.0001
#     Fault 03: 0.9752/0.0000
#     Fault 04: 0.9981/0.0000
#     Fault 05: 0.9865/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9985/0.0000
#     Fault 08: 0.9810/0.0000
#     Fault 09: 0.5314/0.0001
#     Fault 10: 0.9746/0.0000
#     Fault 11: 0.9909/0.0000
#     Fault 12: 0.9855/0.0000
#     Fault 13: 0.9721/0.0001
#     Fault 14: 0.9959/0.0000
#     Fault 15: 0.4331/0.0087
#     Fault 16: 0.9194/0.0014
#     Fault 17: 0.9780/0.0001
#     Fault 18: 0.9637/0.0001
#     Fault 19: 0.9922/0.0000
#     Fault 20: 0.9709/0.0000
#     Fault 21: 0.0005/0.0004
#     Fault 22: 0.7009/0.0000
#     Fault 23: 0.9591/0.0007
#     Fault 24: 0.9908/0.0000
#     Fault 25: 0.9888/0.0000
#     Fault 26: 0.9815/0.0000
#     Fault 27: 0.9909/0.0000
#     Fault 28: 0.9660/0.0002
# Detection TPR: 0.9299
# Detection FPR: 0.0120
# Average Detection Delay (ADD): 31.39
# Total Correct Diagnosis Rate (Total CDR): 0.9683
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8210
# Normalized Mutual Information (NMI): 0.9259
# Unsupervised Clustering Accuracy (ACC): 0.9235
# Epoch: 25/50, average CE loss: 0.0407
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9944/0.0000
#     Fault 02: 0.9934/0.0001
#     Fault 03: 0.9731/0.0000
#     Fault 04: 0.9984/0.0000
#     Fault 05: 0.9835/0.0000
#     Fault 06: 0.9990/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9816/0.0000
#     Fault 09: 0.5298/0.0000
#     Fault 10: 0.9740/0.0000
#     Fault 11: 0.9900/0.0000
#     Fault 12: 0.9855/0.0000
#     Fault 13: 0.9731/0.0001
#     Fault 14: 0.9965/0.0000
#     Fault 15: 0.3456/0.0048
#     Fault 16: 0.9219/0.0019
#     Fault 17: 0.9778/0.0001
#     Fault 18: 0.9639/0.0001
#     Fault 19: 0.9920/0.0000
#     Fault 20: 0.9706/0.0000
#     Fault 21: 0.0004/0.0003
#     Fault 22: 0.6970/0.0000
#     Fault 23: 0.9619/0.0008
#     Fault 24: 0.9900/0.0000
#     Fault 25: 0.9890/0.0000
#     Fault 26: 0.9804/0.0000
#     Fault 27: 0.9909/0.0000
#     Fault 28: 0.9657/0.0001
# Detection TPR: 0.9264
# Detection FPR: 0.0084
# Average Detection Delay (ADD): 30.75
# Total Correct Diagnosis Rate (Total CDR): 0.9684
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8168
# Normalized Mutual Information (NMI): 0.9260
# Unsupervised Clustering Accuracy (ACC): 0.9220
# Epoch: 26/50, average CE loss: 0.0400
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9942/0.0000
#     Fault 02: 0.9936/0.0001
#     Fault 03: 0.9771/0.0000
#     Fault 04: 0.9983/0.0000
#     Fault 05: 0.9848/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9821/0.0000
#     Fault 09: 0.5414/0.0001
#     Fault 10: 0.9736/0.0000
#     Fault 11: 0.9914/0.0000
#     Fault 12: 0.9853/0.0000
#     Fault 13: 0.9722/0.0001
#     Fault 14: 0.9961/0.0000
#     Fault 15: 0.3885/0.0073
#     Fault 16: 0.9263/0.0027
#     Fault 17: 0.9778/0.0001
#     Fault 18: 0.9640/0.0001
#     Fault 19: 0.9921/0.0000
#     Fault 20: 0.9709/0.0000
#     Fault 21: 0.0009/0.0009
#     Fault 22: 0.6864/0.0000
#     Fault 23: 0.9617/0.0008
#     Fault 24: 0.9906/0.0000
#     Fault 25: 0.9890/0.0000
#     Fault 26: 0.9802/0.0000
#     Fault 27: 0.9899/0.0000
#     Fault 28: 0.9671/0.0002
# Detection TPR: 0.9286
# Detection FPR: 0.0125
# Average Detection Delay (ADD): 32.20
# Total Correct Diagnosis Rate (Total CDR): 0.9682
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8180
# Normalized Mutual Information (NMI): 0.9252
# Unsupervised Clustering Accuracy (ACC): 0.9223
# Epoch: 27/50, average CE loss: 0.0394
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9951/0.0000
#     Fault 02: 0.9928/0.0001
#     Fault 03: 0.9754/0.0000
#     Fault 04: 0.9983/0.0000
#     Fault 05: 0.9854/0.0000
#     Fault 06: 0.9991/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9804/0.0000
#     Fault 09: 0.5659/0.0001
#     Fault 10: 0.9739/0.0000
#     Fault 11: 0.9922/0.0000
#     Fault 12: 0.9860/0.0000
#     Fault 13: 0.9740/0.0001
#     Fault 14: 0.9960/0.0000
#     Fault 15: 0.4517/0.0114
#     Fault 16: 0.9163/0.0014
#     Fault 17: 0.9781/0.0001
#     Fault 18: 0.9640/0.0001
#     Fault 19: 0.9912/0.0000
#     Fault 20: 0.9708/0.0000
#     Fault 21: 0.0008/0.0008
#     Fault 22: 0.6618/0.0000
#     Fault 23: 0.9555/0.0003
#     Fault 24: 0.9906/0.0000
#     Fault 25: 0.9874/0.0000
#     Fault 26: 0.9789/0.0000
#     Fault 27: 0.9858/0.0000
#     Fault 28: 0.9649/0.0003
# Detection TPR: 0.9305
# Detection FPR: 0.0149
# Average Detection Delay (ADD): 29.23
# Total Correct Diagnosis Rate (Total CDR): 0.9677
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8196
# Normalized Mutual Information (NMI): 0.9243
# Unsupervised Clustering Accuracy (ACC): 0.9227
# Epoch: 28/50, average CE loss: 0.0387
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9942/0.0000
#     Fault 02: 0.9939/0.0001
#     Fault 03: 0.9749/0.0000
#     Fault 04: 0.9983/0.0000
#     Fault 05: 0.9862/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9822/0.0000
#     Fault 09: 0.4996/0.0001
#     Fault 10: 0.9739/0.0000
#     Fault 11: 0.9905/0.0000
#     Fault 12: 0.9853/0.0000
#     Fault 13: 0.9732/0.0001
#     Fault 14: 0.9960/0.0000
#     Fault 15: 0.4585/0.0126
#     Fault 16: 0.9290/0.0032
#     Fault 17: 0.9778/0.0001
#     Fault 18: 0.9639/0.0001
#     Fault 19: 0.9916/0.0000
#     Fault 20: 0.9706/0.0000
#     Fault 21: 0.0008/0.0010
#     Fault 22: 0.7148/0.0000
#     Fault 23: 0.9554/0.0004
#     Fault 24: 0.9903/0.0000
#     Fault 25: 0.9896/0.0000
#     Fault 26: 0.9809/0.0000
#     Fault 27: 0.9900/0.0000
#     Fault 28: 0.9648/0.0003
# Detection TPR: 0.9313
# Detection FPR: 0.0180
# Average Detection Delay (ADD): 24.06
# Total Correct Diagnosis Rate (Total CDR): 0.9673
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8191
# Normalized Mutual Information (NMI): 0.9241
# Unsupervised Clustering Accuracy (ACC): 0.9222
# Epoch: 29/50, average CE loss: 0.0380
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9949/0.0000
#     Fault 02: 0.9934/0.0000
#     Fault 03: 0.9773/0.0000
#     Fault 04: 0.9984/0.0000
#     Fault 05: 0.9865/0.0000
#     Fault 06: 0.9990/0.0000
#     Fault 07: 0.9985/0.0000
#     Fault 08: 0.9794/0.0000
#     Fault 09: 0.5218/0.0001
#     Fault 10: 0.9742/0.0000
#     Fault 11: 0.9919/0.0000
#     Fault 12: 0.9840/0.0000
#     Fault 13: 0.9729/0.0001
#     Fault 14: 0.9961/0.0000
#     Fault 15: 0.4164/0.0093
#     Fault 16: 0.9290/0.0026
#     Fault 17: 0.9781/0.0001
#     Fault 18: 0.9638/0.0002
#     Fault 19: 0.9921/0.0000
#     Fault 20: 0.9703/0.0000
#     Fault 21: 0.0010/0.0012
#     Fault 22: 0.7011/0.0000
#     Fault 23: 0.9594/0.0005
#     Fault 24: 0.9905/0.0000
#     Fault 25: 0.9887/0.0000
#     Fault 26: 0.9810/0.0000
#     Fault 27: 0.9885/0.0000
#     Fault 28: 0.9646/0.0002
# Detection TPR: 0.9296
# Detection FPR: 0.0145
# Average Detection Delay (ADD): 26.59
# Total Correct Diagnosis Rate (Total CDR): 0.9678
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8185
# Normalized Mutual Information (NMI): 0.9247
# Unsupervised Clustering Accuracy (ACC): 0.9223
# Epoch: 30/50, average CE loss: 0.0375
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9935/0.0000
#     Fault 02: 0.9934/0.0001
#     Fault 03: 0.9772/0.0000
#     Fault 04: 0.9981/0.0000
#     Fault 05: 0.9862/0.0000
#     Fault 06: 0.9991/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9827/0.0000
#     Fault 09: 0.5399/0.0000
#     Fault 10: 0.9740/0.0000
#     Fault 11: 0.9912/0.0000
#     Fault 12: 0.9848/0.0000
#     Fault 13: 0.9738/0.0002
#     Fault 14: 0.9962/0.0000
#     Fault 15: 0.4520/0.0119
#     Fault 16: 0.9235/0.0018
#     Fault 17: 0.9775/0.0001
#     Fault 18: 0.9635/0.0001
#     Fault 19: 0.9917/0.0000
#     Fault 20: 0.9706/0.0000
#     Fault 21: 0.0013/0.0013
#     Fault 22: 0.6792/0.0000
#     Fault 23: 0.9531/0.0002
#     Fault 24: 0.9899/0.0000
#     Fault 25: 0.9885/0.0000
#     Fault 26: 0.9809/0.0000
#     Fault 27: 0.9896/0.0000
#     Fault 28: 0.9629/0.0002
# Detection TPR: 0.9305
# Detection FPR: 0.0159
# Average Detection Delay (ADD): 25.74
# Total Correct Diagnosis Rate (Total CDR): 0.9677
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8190
# Normalized Mutual Information (NMI): 0.9243
# Unsupervised Clustering Accuracy (ACC): 0.9225
# Epoch: 31/50, average CE loss: 0.0368
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9948/0.0000
#     Fault 02: 0.9919/0.0000
#     Fault 03: 0.9780/0.0000
#     Fault 04: 0.9971/0.0000
#     Fault 05: 0.9830/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9816/0.0000
#     Fault 09: 0.4713/0.0001
#     Fault 10: 0.9733/0.0000
#     Fault 11: 0.9915/0.0000
#     Fault 12: 0.9828/0.0001
#     Fault 13: 0.9734/0.0002
#     Fault 14: 0.9960/0.0000
#     Fault 15: 0.4938/0.0154
#     Fault 16: 0.9288/0.0029
#     Fault 17: 0.9779/0.0001
#     Fault 18: 0.9636/0.0001
#     Fault 19: 0.9915/0.0000
#     Fault 20: 0.9707/0.0000
#     Fault 21: 0.0020/0.0023
#     Fault 22: 0.7427/0.0001
#     Fault 23: 0.9406/0.0001
#     Fault 24: 0.9905/0.0000
#     Fault 25: 0.9884/0.0000
#     Fault 26: 0.9810/0.0000
#     Fault 27: 0.9886/0.0000
#     Fault 28: 0.9688/0.0005
# Detection TPR: 0.9326
# Detection FPR: 0.0219
# Average Detection Delay (ADD): 24.77
# Total Correct Diagnosis Rate (Total CDR): 0.9666
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8185
# Normalized Mutual Information (NMI): 0.9227
# Unsupervised Clustering Accuracy (ACC): 0.9217
# Epoch: 32/50, average CE loss: 0.0362
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9952/0.0000
#     Fault 02: 0.9924/0.0000
#     Fault 03: 0.9759/0.0000
#     Fault 04: 0.9982/0.0000
#     Fault 05: 0.9864/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9985/0.0000
#     Fault 08: 0.9816/0.0000
#     Fault 09: 0.4727/0.0001
#     Fault 10: 0.9735/0.0000
#     Fault 11: 0.9899/0.0000
#     Fault 12: 0.9855/0.0000
#     Fault 13: 0.9722/0.0001
#     Fault 14: 0.9957/0.0000
#     Fault 15: 0.4845/0.0159
#     Fault 16: 0.9234/0.0020
#     Fault 17: 0.9778/0.0000
#     Fault 18: 0.9640/0.0002
#     Fault 19: 0.9917/0.0000
#     Fault 20: 0.9703/0.0000
#     Fault 21: 0.0024/0.0025
#     Fault 22: 0.7368/0.0000
#     Fault 23: 0.9496/0.0002
#     Fault 24: 0.9909/0.0000
#     Fault 25: 0.9885/0.0000
#     Fault 26: 0.9812/0.0001
#     Fault 27: 0.9906/0.0000
#     Fault 28: 0.9635/0.0003
# Detection TPR: 0.9320
# Detection FPR: 0.0215
# Average Detection Delay (ADD): 24.63
# Total Correct Diagnosis Rate (Total CDR): 0.9669
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8177
# Normalized Mutual Information (NMI): 0.9232
# Unsupervised Clustering Accuracy (ACC): 0.9215
# Epoch: 33/50, average CE loss: 0.0356
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9953/0.0000
#     Fault 02: 0.9926/0.0000
#     Fault 03: 0.9754/0.0000
#     Fault 04: 0.9984/0.0000
#     Fault 05: 0.9849/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9811/0.0000
#     Fault 09: 0.5038/0.0002
#     Fault 10: 0.9731/0.0000
#     Fault 11: 0.9902/0.0000
#     Fault 12: 0.9845/0.0000
#     Fault 13: 0.9727/0.0001
#     Fault 14: 0.9949/0.0000
#     Fault 15: 0.5184/0.0197
#     Fault 16: 0.9209/0.0022
#     Fault 17: 0.9779/0.0001
#     Fault 18: 0.9638/0.0001
#     Fault 19: 0.9916/0.0000
#     Fault 20: 0.9706/0.0001
#     Fault 21: 0.0031/0.0029
#     Fault 22: 0.7123/0.0001
#     Fault 23: 0.9577/0.0004
#     Fault 24: 0.9905/0.0000
#     Fault 25: 0.9886/0.0000
#     Fault 26: 0.9814/0.0001
#     Fault 27: 0.9908/0.0000
#     Fault 28: 0.9680/0.0005
# Detection TPR: 0.9341
# Detection FPR: 0.0266
# Average Detection Delay (ADD): 23.32
# Total Correct Diagnosis Rate (Total CDR): 0.9665
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8180
# Normalized Mutual Information (NMI): 0.9222
# Unsupervised Clustering Accuracy (ACC): 0.9214
# Epoch: 34/50, average CE loss: 0.0352
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9950/0.0000
#     Fault 02: 0.9927/0.0000
#     Fault 03: 0.9758/0.0000
#     Fault 04: 0.9982/0.0000
#     Fault 05: 0.9833/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9824/0.0000
#     Fault 09: 0.5110/0.0001
#     Fault 10: 0.9740/0.0000
#     Fault 11: 0.9906/0.0000
#     Fault 12: 0.9835/0.0000
#     Fault 13: 0.9737/0.0001
#     Fault 14: 0.9958/0.0000
#     Fault 15: 0.4143/0.0094
#     Fault 16: 0.9304/0.0029
#     Fault 17: 0.9781/0.0001
#     Fault 18: 0.9637/0.0002
#     Fault 19: 0.9915/0.0000
#     Fault 20: 0.9708/0.0000
#     Fault 21: 0.0030/0.0028
#     Fault 22: 0.7073/0.0000
#     Fault 23: 0.9511/0.0002
#     Fault 24: 0.9899/0.0000
#     Fault 25: 0.9892/0.0000
#     Fault 26: 0.9817/0.0000
#     Fault 27: 0.9908/0.0000
#     Fault 28: 0.9655/0.0003
# Detection TPR: 0.9293
# Detection FPR: 0.0163
# Average Detection Delay (ADD): 25.10
# Total Correct Diagnosis Rate (Total CDR): 0.9677
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8165
# Normalized Mutual Information (NMI): 0.9238
# Unsupervised Clustering Accuracy (ACC): 0.9215
# Epoch: 35/50, average CE loss: 0.0346
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9954/0.0000
#     Fault 02: 0.9928/0.0000
#     Fault 03: 0.9784/0.0000
#     Fault 04: 0.9982/0.0000
#     Fault 05: 0.9823/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9816/0.0000
#     Fault 09: 0.5257/0.0001
#     Fault 10: 0.9741/0.0001
#     Fault 11: 0.9907/0.0000
#     Fault 12: 0.9835/0.0000
#     Fault 13: 0.9734/0.0001
#     Fault 14: 0.9960/0.0000
#     Fault 15: 0.3682/0.0069
#     Fault 16: 0.9209/0.0021
#     Fault 17: 0.9781/0.0001
#     Fault 18: 0.9630/0.0001
#     Fault 19: 0.9897/0.0000
#     Fault 20: 0.9699/0.0001
#     Fault 21: 0.0035/0.0030
#     Fault 22: 0.6894/0.0000
#     Fault 23: 0.9630/0.0012
#     Fault 24: 0.9903/0.0000
#     Fault 25: 0.9896/0.0000
#     Fault 26: 0.9819/0.0000
#     Fault 27: 0.9899/0.0000
#     Fault 28: 0.9663/0.0003
# Detection TPR: 0.9277
# Detection FPR: 0.0145
# Average Detection Delay (ADD): 26.02
# Total Correct Diagnosis Rate (Total CDR): 0.9675
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8147
# Normalized Mutual Information (NMI): 0.9234
# Unsupervised Clustering Accuracy (ACC): 0.9207
# Epoch: 36/50, average CE loss: 0.0341
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9955/0.0000
#     Fault 02: 0.9924/0.0000
#     Fault 03: 0.9748/0.0000
#     Fault 04: 0.9979/0.0000
#     Fault 05: 0.9871/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9985/0.0000
#     Fault 08: 0.9807/0.0000
#     Fault 09: 0.5216/0.0001
#     Fault 10: 0.9739/0.0000
#     Fault 11: 0.9902/0.0000
#     Fault 12: 0.9839/0.0000
#     Fault 13: 0.9713/0.0001
#     Fault 14: 0.9953/0.0000
#     Fault 15: 0.4393/0.0118
#     Fault 16: 0.9277/0.0031
#     Fault 17: 0.9783/0.0002
#     Fault 18: 0.9635/0.0001
#     Fault 19: 0.9916/0.0000
#     Fault 20: 0.9704/0.0001
#     Fault 21: 0.0035/0.0038
#     Fault 22: 0.6937/0.0001
#     Fault 23: 0.9629/0.0011
#     Fault 24: 0.9904/0.0000
#     Fault 25: 0.9890/0.0000
#     Fault 26: 0.9817/0.0001
#     Fault 27: 0.9909/0.0000
#     Fault 28: 0.9653/0.0003
# Detection TPR: 0.9310
# Detection FPR: 0.0209
# Average Detection Delay (ADD): 23.09
# Total Correct Diagnosis Rate (Total CDR): 0.9671
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8163
# Normalized Mutual Information (NMI): 0.9223
# Unsupervised Clustering Accuracy (ACC): 0.9211
# Epoch: 37/50, average CE loss: 0.0337
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9945/0.0000
#     Fault 02: 0.9929/0.0001
#     Fault 03: 0.9761/0.0000
#     Fault 04: 0.9980/0.0000
#     Fault 05: 0.9869/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9818/0.0000
#     Fault 09: 0.5198/0.0001
#     Fault 10: 0.9739/0.0001
#     Fault 11: 0.9918/0.0000
#     Fault 12: 0.9834/0.0000
#     Fault 13: 0.9727/0.0001
#     Fault 14: 0.9947/0.0000
#     Fault 15: 0.4255/0.0113
#     Fault 16: 0.9268/0.0028
#     Fault 17: 0.9777/0.0000
#     Fault 18: 0.9630/0.0000
#     Fault 19: 0.9912/0.0000
#     Fault 20: 0.9709/0.0001
#     Fault 21: 0.0043/0.0041
#     Fault 22: 0.6964/0.0001
#     Fault 23: 0.9594/0.0006
#     Fault 24: 0.9904/0.0000
#     Fault 25: 0.9891/0.0000
#     Fault 26: 0.9797/0.0001
#     Fault 27: 0.9894/0.0000
#     Fault 28: 0.9647/0.0004
# Detection TPR: 0.9303
# Detection FPR: 0.0198
# Average Detection Delay (ADD): 25.32
# Total Correct Diagnosis Rate (Total CDR): 0.9672
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8157
# Normalized Mutual Information (NMI): 0.9227
# Unsupervised Clustering Accuracy (ACC): 0.9209
# Epoch: 38/50, average CE loss: 0.0331
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9947/0.0000
#     Fault 02: 0.9917/0.0001
#     Fault 03: 0.9789/0.0000
#     Fault 04: 0.9982/0.0000
#     Fault 05: 0.9881/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9821/0.0001
#     Fault 09: 0.5385/0.0001
#     Fault 10: 0.9729/0.0000
#     Fault 11: 0.9908/0.0000
#     Fault 12: 0.9838/0.0001
#     Fault 13: 0.9740/0.0001
#     Fault 14: 0.9950/0.0000
#     Fault 15: 0.5053/0.0178
#     Fault 16: 0.9280/0.0032
#     Fault 17: 0.9782/0.0002
#     Fault 18: 0.9632/0.0001
#     Fault 19: 0.9911/0.0000
#     Fault 20: 0.9698/0.0001
#     Fault 21: 0.0061/0.0053
#     Fault 22: 0.6804/0.0000
#     Fault 23: 0.9544/0.0005
#     Fault 24: 0.9898/0.0000
#     Fault 25: 0.9894/0.0000
#     Fault 26: 0.9811/0.0001
#     Fault 27: 0.9907/0.0000
#     Fault 28: 0.9584/0.0001
# Detection TPR: 0.9337
# Detection FPR: 0.0279
# Average Detection Delay (ADD): 21.68
# Total Correct Diagnosis Rate (Total CDR): 0.9667
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8161
# Normalized Mutual Information (NMI): 0.9211
# Unsupervised Clustering Accuracy (ACC): 0.9209
# Epoch: 39/50, average CE loss: 0.0326
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9949/0.0000
#     Fault 02: 0.9932/0.0000
#     Fault 03: 0.9715/0.0000
#     Fault 04: 0.9976/0.0000
#     Fault 05: 0.9841/0.0000
#     Fault 06: 0.9991/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9828/0.0000
#     Fault 09: 0.5159/0.0001
#     Fault 10: 0.9732/0.0001
#     Fault 11: 0.9897/0.0000
#     Fault 12: 0.9845/0.0000
#     Fault 13: 0.9705/0.0001
#     Fault 14: 0.9959/0.0000
#     Fault 15: 0.4085/0.0103
#     Fault 16: 0.9301/0.0036
#     Fault 17: 0.9783/0.0002
#     Fault 18: 0.9627/0.0000
#     Fault 19: 0.9916/0.0000
#     Fault 20: 0.9706/0.0001
#     Fault 21: 0.0081/0.0060
#     Fault 22: 0.6975/0.0000
#     Fault 23: 0.9634/0.0012
#     Fault 24: 0.9903/0.0000
#     Fault 25: 0.9886/0.0000
#     Fault 26: 0.9803/0.0000
#     Fault 27: 0.9914/0.0000
#     Fault 28: 0.9665/0.0006
# Detection TPR: 0.9301
# Detection FPR: 0.0224
# Average Detection Delay (ADD): 24.31
# Total Correct Diagnosis Rate (Total CDR): 0.9669
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8132
# Normalized Mutual Information (NMI): 0.9212
# Unsupervised Clustering Accuracy (ACC): 0.9199
# Epoch: 40/50, average CE loss: 0.0323
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9953/0.0000
#     Fault 02: 0.9933/0.0000
#     Fault 03: 0.9775/0.0000
#     Fault 04: 0.9982/0.0000
#     Fault 05: 0.9861/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9805/0.0000
#     Fault 09: 0.4568/0.0001
#     Fault 10: 0.9727/0.0000
#     Fault 11: 0.9916/0.0000
#     Fault 12: 0.9834/0.0001
#     Fault 13: 0.9721/0.0001
#     Fault 14: 0.9954/0.0000
#     Fault 15: 0.4129/0.0106
#     Fault 16: 0.9245/0.0031
#     Fault 17: 0.9784/0.0002
#     Fault 18: 0.9636/0.0002
#     Fault 19: 0.9910/0.0000
#     Fault 20: 0.9702/0.0001
#     Fault 21: 0.0057/0.0041
#     Fault 22: 0.7443/0.0001
#     Fault 23: 0.9568/0.0004
#     Fault 24: 0.9902/0.0000
#     Fault 25: 0.9880/0.0001
#     Fault 26: 0.9814/0.0001
#     Fault 27: 0.9882/0.0000
#     Fault 28: 0.9650/0.0004
# Detection TPR: 0.9297
# Detection FPR: 0.0196
# Average Detection Delay (ADD): 23.32
# Total Correct Diagnosis Rate (Total CDR): 0.9666
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8145
# Normalized Mutual Information (NMI): 0.9222
# Unsupervised Clustering Accuracy (ACC): 0.9201
# Epoch: 41/50, average CE loss: 0.0318
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9949/0.0000
#     Fault 02: 0.9932/0.0000
#     Fault 03: 0.9777/0.0000
#     Fault 04: 0.9979/0.0000
#     Fault 05: 0.9870/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9814/0.0000
#     Fault 09: 0.5222/0.0001
#     Fault 10: 0.9735/0.0001
#     Fault 11: 0.9910/0.0000
#     Fault 12: 0.9855/0.0001
#     Fault 13: 0.9725/0.0000
#     Fault 14: 0.9960/0.0000
#     Fault 15: 0.3216/0.0047
#     Fault 16: 0.9275/0.0034
#     Fault 17: 0.9782/0.0002
#     Fault 18: 0.9639/0.0002
#     Fault 19: 0.9909/0.0000
#     Fault 20: 0.9706/0.0001
#     Fault 21: 0.0063/0.0046
#     Fault 22: 0.7004/0.0001
#     Fault 23: 0.9669/0.0021
#     Fault 24: 0.9899/0.0000
#     Fault 25: 0.9887/0.0000
#     Fault 26: 0.9816/0.0001
#     Fault 27: 0.9900/0.0000
#     Fault 28: 0.9569/0.0001
# Detection TPR: 0.9267
# Detection FPR: 0.0160
# Average Detection Delay (ADD): 24.53
# Total Correct Diagnosis Rate (Total CDR): 0.9675
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8115
# Normalized Mutual Information (NMI): 0.9224
# Unsupervised Clustering Accuracy (ACC): 0.9196
# Epoch: 42/50, average CE loss: 0.0316
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9948/0.0000
#     Fault 02: 0.9926/0.0000
#     Fault 03: 0.9766/0.0000
#     Fault 04: 0.9982/0.0000
#     Fault 05: 0.9863/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9806/0.0000
#     Fault 09: 0.5253/0.0001
#     Fault 10: 0.9735/0.0000
#     Fault 11: 0.9912/0.0000
#     Fault 12: 0.9847/0.0001
#     Fault 13: 0.9731/0.0001
#     Fault 14: 0.9955/0.0000
#     Fault 15: 0.3876/0.0083
#     Fault 16: 0.9289/0.0034
#     Fault 17: 0.9782/0.0001
#     Fault 18: 0.9634/0.0002
#     Fault 19: 0.9906/0.0000
#     Fault 20: 0.9694/0.0001
#     Fault 21: 0.0047/0.0041
#     Fault 22: 0.6914/0.0000
#     Fault 23: 0.9664/0.0022
#     Fault 24: 0.9904/0.0000
#     Fault 25: 0.9857/0.0000
#     Fault 26: 0.9812/0.0002
#     Fault 27: 0.9886/0.0000
#     Fault 28: 0.9645/0.0004
# Detection TPR: 0.9293
# Detection FPR: 0.0194
# Average Detection Delay (ADD): 23.66
# Total Correct Diagnosis Rate (Total CDR): 0.9670
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8139
# Normalized Mutual Information (NMI): 0.9214
# Unsupervised Clustering Accuracy (ACC): 0.9202
# Epoch: 43/50, average CE loss: 0.0311
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9950/0.0000
#     Fault 02: 0.9927/0.0000
#     Fault 03: 0.9765/0.0000
#     Fault 04: 0.9983/0.0000
#     Fault 05: 0.9859/0.0000
#     Fault 06: 0.9991/0.0000
#     Fault 07: 0.9985/0.0000
#     Fault 08: 0.9814/0.0000
#     Fault 09: 0.5006/0.0001
#     Fault 10: 0.9745/0.0001
#     Fault 11: 0.9907/0.0000
#     Fault 12: 0.9843/0.0001
#     Fault 13: 0.9734/0.0002
#     Fault 14: 0.9960/0.0000
#     Fault 15: 0.4221/0.0112
#     Fault 16: 0.9165/0.0018
#     Fault 17: 0.9781/0.0001
#     Fault 18: 0.9633/0.0003
#     Fault 19: 0.9911/0.0000
#     Fault 20: 0.9704/0.0002
#     Fault 21: 0.0102/0.0069
#     Fault 22: 0.7101/0.0001
#     Fault 23: 0.9653/0.0019
#     Fault 24: 0.9901/0.0000
#     Fault 25: 0.9893/0.0001
#     Fault 26: 0.9810/0.0002
#     Fault 27: 0.9898/0.0000
#     Fault 28: 0.9649/0.0005
# Detection TPR: 0.9306
# Detection FPR: 0.0241
# Average Detection Delay (ADD): 20.94
# Total Correct Diagnosis Rate (Total CDR): 0.9667
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8129
# Normalized Mutual Information (NMI): 0.9206
# Unsupervised Clustering Accuracy (ACC): 0.9197
# Epoch: 44/50, average CE loss: 0.0306
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9954/0.0000
#     Fault 02: 0.9915/0.0000
#     Fault 03: 0.9732/0.0000
#     Fault 04: 0.9976/0.0000
#     Fault 05: 0.9856/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9792/0.0000
#     Fault 09: 0.5129/0.0001
#     Fault 10: 0.9737/0.0000
#     Fault 11: 0.9916/0.0000
#     Fault 12: 0.9832/0.0000
#     Fault 13: 0.9735/0.0001
#     Fault 14: 0.9959/0.0000
#     Fault 15: 0.3719/0.0076
#     Fault 16: 0.9295/0.0039
#     Fault 17: 0.9779/0.0004
#     Fault 18: 0.9626/0.0000
#     Fault 19: 0.9912/0.0001
#     Fault 20: 0.9693/0.0000
#     Fault 21: 0.0061/0.0049
#     Fault 22: 0.6961/0.0001
#     Fault 23: 0.9675/0.0027
#     Fault 24: 0.9900/0.0000
#     Fault 25: 0.9891/0.0001
#     Fault 26: 0.9779/0.0000
#     Fault 27: 0.9889/0.0000
#     Fault 28: 0.9620/0.0003
# Detection TPR: 0.9288
# Detection FPR: 0.0205
# Average Detection Delay (ADD): 22.51
# Total Correct Diagnosis Rate (Total CDR): 0.9664
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8119
# Normalized Mutual Information (NMI): 0.9204
# Unsupervised Clustering Accuracy (ACC): 0.9191
# Epoch: 45/50, average CE loss: 0.0304
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9950/0.0000
#     Fault 02: 0.9926/0.0000
#     Fault 03: 0.9740/0.0000
#     Fault 04: 0.9977/0.0000
#     Fault 05: 0.9865/0.0000
#     Fault 06: 0.9990/0.0000
#     Fault 07: 0.9984/0.0000
#     Fault 08: 0.9814/0.0001
#     Fault 09: 0.4686/0.0002
#     Fault 10: 0.9737/0.0000
#     Fault 11: 0.9915/0.0000
#     Fault 12: 0.9836/0.0001
#     Fault 13: 0.9725/0.0003
#     Fault 14: 0.9960/0.0000
#     Fault 15: 0.3773/0.0079
#     Fault 16: 0.9297/0.0038
#     Fault 17: 0.9779/0.0002
#     Fault 18: 0.9632/0.0002
#     Fault 19: 0.9909/0.0001
#     Fault 20: 0.9700/0.0001
#     Fault 21: 0.0075/0.0060
#     Fault 22: 0.7349/0.0001
#     Fault 23: 0.9645/0.0014
#     Fault 24: 0.9900/0.0000
#     Fault 25: 0.9890/0.0001
#     Fault 26: 0.9787/0.0001
#     Fault 27: 0.9895/0.0000
#     Fault 28: 0.9641/0.0004
# Detection TPR: 0.9291
# Detection FPR: 0.0213
# Average Detection Delay (ADD): 22.74
# Total Correct Diagnosis Rate (Total CDR): 0.9662
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8122
# Normalized Mutual Information (NMI): 0.9207
# Unsupervised Clustering Accuracy (ACC): 0.9191
# Epoch: 46/50, average CE loss: 0.0301
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9947/0.0000
#     Fault 02: 0.9930/0.0000
#     Fault 03: 0.9758/0.0000
#     Fault 04: 0.9983/0.0000
#     Fault 05: 0.9860/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9814/0.0001
#     Fault 09: 0.5305/0.0001
#     Fault 10: 0.9735/0.0000
#     Fault 11: 0.9915/0.0000
#     Fault 12: 0.9832/0.0000
#     Fault 13: 0.9734/0.0001
#     Fault 14: 0.9961/0.0000
#     Fault 15: 0.3696/0.0074
#     Fault 16: 0.9250/0.0029
#     Fault 17: 0.9772/0.0001
#     Fault 18: 0.9636/0.0002
#     Fault 19: 0.9908/0.0001
#     Fault 20: 0.9702/0.0001
#     Fault 21: 0.0048/0.0035
#     Fault 22: 0.6918/0.0001
#     Fault 23: 0.9608/0.0008
#     Fault 24: 0.9900/0.0000
#     Fault 25: 0.9896/0.0001
#     Fault 26: 0.9815/0.0001
#     Fault 27: 0.9875/0.0000
#     Fault 28: 0.9634/0.0003
# Detection TPR: 0.9279
# Detection FPR: 0.0159
# Average Detection Delay (ADD): 25.44
# Total Correct Diagnosis Rate (Total CDR): 0.9677
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8138
# Normalized Mutual Information (NMI): 0.9227
# Unsupervised Clustering Accuracy (ACC): 0.9206
# Epoch: 47/50, average CE loss: 0.0296
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9951/0.0000
#     Fault 02: 0.9925/0.0000
#     Fault 03: 0.9769/0.0000
#     Fault 04: 0.9971/0.0000
#     Fault 05: 0.9855/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9821/0.0001
#     Fault 09: 0.4981/0.0001
#     Fault 10: 0.9742/0.0001
#     Fault 11: 0.9920/0.0000
#     Fault 12: 0.9827/0.0000
#     Fault 13: 0.9731/0.0002
#     Fault 14: 0.9959/0.0000
#     Fault 15: 0.3752/0.0080
#     Fault 16: 0.9279/0.0035
#     Fault 17: 0.9781/0.0001
#     Fault 18: 0.9633/0.0002
#     Fault 19: 0.9909/0.0000
#     Fault 20: 0.9705/0.0001
#     Fault 21: 0.0064/0.0050
#     Fault 22: 0.7043/0.0001
#     Fault 23: 0.9664/0.0022
#     Fault 24: 0.9904/0.0001
#     Fault 25: 0.9886/0.0000
#     Fault 26: 0.9812/0.0001
#     Fault 27: 0.9871/0.0000
#     Fault 28: 0.9626/0.0003
# Detection TPR: 0.9288
# Detection FPR: 0.0204
# Average Detection Delay (ADD): 22.05
# Total Correct Diagnosis Rate (Total CDR): 0.9665
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8122
# Normalized Mutual Information (NMI): 0.9208
# Unsupervised Clustering Accuracy (ACC): 0.9193
# Epoch: 48/50, average CE loss: 0.0292
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9945/0.0000
#     Fault 02: 0.9922/0.0000
#     Fault 03: 0.9700/0.0000
#     Fault 04: 0.9979/0.0000
#     Fault 05: 0.9854/0.0000
#     Fault 06: 0.9980/0.0000
#     Fault 07: 0.9983/0.0000
#     Fault 08: 0.9827/0.0000
#     Fault 09: 0.4886/0.0001
#     Fault 10: 0.9732/0.0000
#     Fault 11: 0.9917/0.0000
#     Fault 12: 0.9837/0.0001
#     Fault 13: 0.9733/0.0002
#     Fault 14: 0.9958/0.0000
#     Fault 15: 0.4030/0.0095
#     Fault 16: 0.9225/0.0027
#     Fault 17: 0.9777/0.0004
#     Fault 18: 0.9636/0.0002
#     Fault 19: 0.9906/0.0000
#     Fault 20: 0.9702/0.0001
#     Fault 21: 0.0128/0.0091
#     Fault 22: 0.7129/0.0001
#     Fault 23: 0.9501/0.0001
#     Fault 24: 0.9899/0.0000
#     Fault 25: 0.9885/0.0000
#     Fault 26: 0.9812/0.0000
#     Fault 27: 0.9868/0.0000
#     Fault 28: 0.9621/0.0002
# Detection TPR: 0.9292
# Detection FPR: 0.0230
# Average Detection Delay (ADD): 21.00
# Total Correct Diagnosis Rate (Total CDR): 0.9661
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8108
# Normalized Mutual Information (NMI): 0.9201
# Unsupervised Clustering Accuracy (ACC): 0.9186
# Epoch: 49/50, average CE loss: 0.0289
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9949/0.0000
#     Fault 02: 0.9912/0.0000
#     Fault 03: 0.9776/0.0000
#     Fault 04: 0.9982/0.0000
#     Fault 05: 0.9850/0.0000
#     Fault 06: 0.9988/0.0000
#     Fault 07: 0.9986/0.0000
#     Fault 08: 0.9800/0.0000
#     Fault 09: 0.5232/0.0001
#     Fault 10: 0.9750/0.0001
#     Fault 11: 0.9909/0.0000
#     Fault 12: 0.9842/0.0001
#     Fault 13: 0.9734/0.0002
#     Fault 14: 0.9960/0.0000
#     Fault 15: 0.3222/0.0054
#     Fault 16: 0.9210/0.0023
#     Fault 17: 0.9779/0.0002
#     Fault 18: 0.9635/0.0002
#     Fault 19: 0.9909/0.0001
#     Fault 20: 0.9699/0.0001
#     Fault 21: 0.0067/0.0057
#     Fault 22: 0.6850/0.0000
#     Fault 23: 0.9665/0.0022
#     Fault 24: 0.9898/0.0000
#     Fault 25: 0.9886/0.0000
#     Fault 26: 0.9816/0.0002
#     Fault 27: 0.9876/0.0000
#     Fault 28: 0.9604/0.0002
# Detection TPR: 0.9263
# Detection FPR: 0.0172
# Average Detection Delay (ADD): 22.23
# Total Correct Diagnosis Rate (Total CDR): 0.9669
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8098
# Normalized Mutual Information (NMI): 0.9210
# Unsupervised Clustering Accuracy (ACC): 0.9186
# Epoch: 50/50, average CE loss: 0.0286
# FDD metrics
# -----------------
# TPR/FPR:
#     Fault 01: 0.9942/0.0000
#     Fault 02: 0.9929/0.0001
#     Fault 03: 0.9731/0.0000
#     Fault 04: 0.9981/0.0000
#     Fault 05: 0.9870/0.0000
#     Fault 06: 0.9992/0.0000
#     Fault 07: 0.9984/0.0000
#     Fault 08: 0.9824/0.0001
#     Fault 09: 0.5347/0.0001
#     Fault 10: 0.9742/0.0000
#     Fault 11: 0.9915/0.0000
#     Fault 12: 0.9836/0.0001
#     Fault 13: 0.9738/0.0002
#     Fault 14: 0.9960/0.0000
#     Fault 15: 0.3474/0.0062
#     Fault 16: 0.9260/0.0032
#     Fault 17: 0.9778/0.0001
#     Fault 18: 0.9629/0.0003
#     Fault 19: 0.9901/0.0000
#     Fault 20: 0.9706/0.0001
#     Fault 21: 0.0056/0.0042
#     Fault 22: 0.6648/0.0000
#     Fault 23: 0.9674/0.0025
#     Fault 24: 0.9902/0.0001
#     Fault 25: 0.9890/0.0001
#     Fault 26: 0.9820/0.0002
#     Fault 27: 0.9870/0.0000
#     Fault 28: 0.9617/0.0002
# Detection TPR: 0.9276
# Detection FPR: 0.0177
# Average Detection Delay (ADD): 21.32
# Total Correct Diagnosis Rate (Total CDR): 0.9664
#
# Clustering metrics
# -----------------
# Adjusted Rand Index (ARI): 0.8118
# Normalized Mutual Information (NMI): 0.9210
# Unsupervised Clustering Accuracy (ACC): 0.9191
# Wall time: 13h 12min 25s
